# %% [markdown]
# <a href="https://colab.research.google.com/github/Hibashanti/Prediction-Product-Sale/blob/main/Prediction_Product_Sale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prediction of Product Sale
# - Author : Hiba Shanti

# %% [markdown]
# ## Project overview

# %% [markdown]
# ## 1- Load and Inspect Data

# %%
path="/content/drive/MyDrive/Axsos Academy/AXSOSACADEMY-1/01-Fundamentals/Week02/Data/sales_predictions_2023.csv"

# %% [markdown]
# ### 1.1-Imports :

# %%
from statistics import mode
import pandas as pd
df_sales=pd.read_csv(path)
df_sales
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-149809124.py in <cell line: 0>()
#       1 from statistics import mode
#       2 import pandas as pd
# ----> 3 df_sales=pd.read_csv(path)
#       4 df_sales
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Axsos Academy/AXSOSACADEMY-1/01-Fundamentals/Week02/Data/sales_predictions_2023.csv'

# %%
df_sales.info()

# %%
df_sales.head()

# %% [markdown]
# ## 2-Clean Data

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# #### Number of Rows
# '8523'
#
# #### Number od Columns
# '12'

# %%
df_sales.dtypes

# %% [markdown]
# ###Type of Data
# - float 4
# - Int    1
# - object 7

# %% [markdown]
# ## 3-Feature Inspection

# %% [markdown]
# - 3.1-Inspecting and Droping Duplicates

# %%
#Check for Duplicates
df_sales.duplicated().sum()

# %% [markdown]
# - there is zero duplicates in the dataset

# %% [markdown]
# - 3.2-Inspecting Missing Values

# %%
#Check for Missing Values
df_sales.isna().sum()

# %%
df_sales["Item_Weight"].dtypes

# %%
df_sales["Item_Weight"]=df_sales["Item_Weight"].fillna(-1)
df_sales["Item_Weight"]

# %%
df_sales["Item_Weight"].isna().sum()

# %%
df_sales["Outlet_Size"].dtypes

# %%
df_sales["Outlet_Size"].value_counts()

# %%
df_sales["Outlet_Size"]=df_sales["Outlet_Size"].fillna("MISSING")
df_sales["Outlet_Size"]

# %%
df_sales["Outlet_Size"].value_counts()

# %%
df_sales.isna().sum()

# %% [markdown]
# - Inspect Inconsistanses
#   - 1- Catagorical Values
#   - 2- Numerical Values

# %%
# Display categorical columns
cat_col=df_sales.select_dtypes("object").columns
cat_col

# %%
#to check for inconsistances in each category:
for col in cat_col :
  print(f"Value Counts for {col}")
  print(df_sales[col].value_counts())
  print('\n')

# %%
df_sales["Item_Fat_Content"]=df_sales["Item_Fat_Content"].replace({"LF":"Low Fat", "low fat":"Low Fat", "reg" : "Regular"})
df_sales["Item_Fat_Content"].value_counts()

# %% [markdown]
# - Summary Statistics for numerical Data

# %%
# Display numeriacl columns
num_col=df_sales.select_dtypes("number").columns
num_col

# %%
print(f"The summury statistics for the numerical values is")
for col in num_col :
  mean_value=df_sales[col].mean().round(2)
  median_value=df_sales[col].median()
  mode_value=df_sales[col].mode()
  print(f"The mean valve is {mean_value},the median value is {median_value} the mode value is {mode_value}")
  print("\n")
